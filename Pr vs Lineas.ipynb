# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#db = pd.read_excel('Solicitudes-2017.xlsx','Todos')

# %%
db2=pd.read_excel('solicitudes.xlsx','Hoja1', parse_dates=['REQ_DT'], index_col='REQ_DT')

# %%
db3=pd.read_excel('Solicitudes-2018.xlsx','Hoja1', parse_dates=['REQ_DT'], index_col='REQ_DT')

# %%
db2.head(2)
# Out:
#            BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# REQ_DT
# 2017-01-03         CHL01   81258          0             1             1
# 2017-01-03         CHL01   81259          0             1             1
#
#             DISTRIB_LINE_REQ REQ_STATUS BUDGET_HDR_STATUS REQUESTOR_ID  \
# REQ_DT
# 2017-01-03                 1          D                 V    200041928
# 2017-01-03                 1          D                 V    200041928
#
#             ACCOUNT         ...           REQ_LN_STATUS  BUDGET_DT  \
# REQ_DT                      ...
# 2017-01-03  1000000         ...                       D 2017-01-03
# 2017-01-03  1000000         ...                       D 2017-01-03
#
#             ATTACH_DOC  APPROVAL_DT KK_TRAN_DT Fec/Hor Ult Actualizacion  \
# REQ_DT
# 2017-01-03           Y   2017-01-04 2017-01-03       2017-01-03 08:20:55
# 2017-01-03           Y   2017-01-04 2017-01-03       2017-01-03 08:35:38
#
# ...

# %%
db2.dtypes
# Out:
# BUSINESS_UNIT                        object
# REQ_ID                                int64
# Solicitud                             int64
# REQ_LINE_NBR                          int64
# REQ_LN_SCHED                          int64
# DISTRIB_LINE_REQ                      int64
# REQ_STATUS                           object
# BUDGET_HDR_STATUS                    object
# REQUESTOR_ID                         object
# ACCOUNT                               int64
# DEPTID                              float64
# OPERATING_UNIT                        int64
# PRODUCT                             float64
# CHARTFIELD2                         float64
# CHARTFIELD3                          object
# PROJECT_ID                           object
# AFFILIATE                           float64
# INV_ITEM_ID                          object
# ITM_ID_VNDR                          object
# DESCR                                object
# QTY_REQ                             float64
# ...

# %%
db3.dtypes
# Out:
# BUSINESS_UNIT                        object
# REQ_ID                                int64
# REQ_LINE_NBR                          int64
# REQ_LN_SCHED                          int64
# DISTRIB_LINE_REQ                      int64
# REQ_STATUS                           object
# BUDGET_HDR_STATUS                    object
# REQUESTOR_ID                         object
# ACCOUNT                               int64
# DEPTID                                int64
# OPERATING_UNIT                      float64
# PRODUCT                             float64
# CHARTFIELD2                         float64
# CHARTFIELD3                         float64
# PROJECT_ID                           object
# AFFILIATE                           float64
# INV_ITEM_ID                          object
# DESCR                                object
# QTY_REQ                             float64
# MERCHANDISE_AMT                     float64
# CURRENCY_REQ                         object
# ...

# %% [markdown]
# <font color='black'><Bold>**Cantidad de Solicitante anual**</font><br>

# %%
#Encuentra la cantidad de Requestors segun BU y linea 1 (Anual)
#A=db2.groupby(['BUSINESS_UNIT','Cantidad de lineas','Mes de requerimiento','Insitucion'])['REQ_ID'].get_group(('CHL01','1','Enero','AIEP')).value_counts()
B2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('AIEP',1)).nunique()
C2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UNAB',1)).nunique()
D2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UDLA',1)).nunique()
E2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('IESA',1)).nunique()
F2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UVM',1)).nunique()
G2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UPN',1)).nunique()
H2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UPC',1)).nunique()
I2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('Cibertec',1)).nunique()

Y=[ B2,C2,D2,E2,F2,G2,H2,I2 ]
X=["AIEP","UNAB","UDLA","IESA","UVM","UPM","UPC","CIBERTEC"]

sns.barplot(X, Y) #x="day", y="total_bill",
X
Y
# Out:
# [61, 142, 77, 4, 2, 102, 188, 33]

# %%
#Encuentra la cantidad de Requestors segun BU y linea 1 (Anual)
B4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('AIEP',1)).nunique()
C4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UNAB',1)).nunique()
D4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UDLA',1)).nunique()
E4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('IESA',1)).nunique()
F4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UVM',1)).nunique()
G4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UPN',1)).nunique()
H4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UPC',1)).nunique()
I4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('Cibertec',1)).nunique()

Y2=[ B4,C4,D4,E4,F4,G4,H4,I4 ]
X2=["AIEP","UNAB","UDLA","IESA","UVM","UPN","UPC","CIBERTEC"]

sns.barplot(X2, Y2)
Y2

#x="day", y="total_bill",
# Out:
# [61, 142, 77, 4, 2, 102, 188, 33]

# %%
#Cantidad de lineas mensuales y anuales

#Lineas_Mensuales=db2.groupby(['Mes de requerimiento','Insitucion'])['Cantidad de lineas'].get_group(('Enero','AIEP')).count()
Lineas_Anuales_1=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('AIEP')).count()
Lineas_Anuales_2=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UNAB')).count()
Lineas_Anuales_3=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UDLA')).count()
Lineas_Anuales_4=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UVM')).count()
Lineas_Anuales_5=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('IESA')).count()
Lineas_Anuales_6=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UPC')).count()
Lineas_Anuales_7=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UPN')).count()
Lineas_Anuales_8=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('Cibertec')).count()

Tiempo_Total_AIEP=(Lineas_Anuales_1 * 4)/(60*8)
Tiempo_Total_UNAB=(Lineas_Anuales_2 * 4)/(60*8)
Tiempo_Total_UDLA=(Lineas_Anuales_3 * 4)/(60*8)
Tiempo_Total_UVM=(Lineas_Anuales_4 * 4)/(60*8)
Tiempo_Total_IESA=(Lineas_Anuales_5 * 4)/(60*8)
Tiempo_Total_UPC=(Lineas_Anuales_6 * 4)/(60*8)
Tiempo_Total_UPN=(Lineas_Anuales_7 * 4)/(60*8)
Tiempo_Total_Cibertec=(Lineas_Anuales_8 * 4)/(60*8)

#Lineas_Anuales_2=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UNAB')).count()
#Lineas_Anuales_3=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UDLA')).count()
#Lineas_Anuales_4=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UVM')).count()
#Lineas_Anuales_5=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('IESA')).count()
#Lineas_Anuales_6=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UVM')).count()
#Lineas_Anuales_7=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UPC')).count()
#Lineas_Anuales_8=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('UPN')).count()
#Lineas_Anuales_9=db2.groupby(['Insitucion'])['Cantidad de lineas'].get_group(('Cibertec')).count()

#Lineas_Anuales_1
Z6 = [Lineas_Anuales_1, Lineas_Anuales_2,Lineas_Anuales_3,Lineas_Anuales_4,Lineas_Anuales_5]
Y6 = [Tiempo_Total_AIEP,Tiempo_Total_UNAB,Tiempo_Total_UDLA,Tiempo_Total_UVM,Tiempo_Total_IESA]
X6=["AIEP","UNAB","UDLA","IESA","UVM"]


graph = sns.barplot(X6, Y6)
graph.set_xlabel('Institucion')
graph.set_ylabel('Dias de procesamiento (4 min/lineas)')
plt.show()



#Dias de ahorro, a 4 minutos la linea, 8 horas/dia.

# %% [markdown]
# # Evolucion en el N° REQ_ID y la cantidad de linea (REQ_LINE_NBR)

# %%
#http://benalexkeen.com/resampling-time-series-data-with-pandas/
Quantity_Request_line=db2['Comparador'].resample('B').count()
Quantity_Request=db2['Comparador'].resample('B').nunique()

# %%
Quantity_Request_line2=db3['Comparador'].resample('B').count()
Quantity_Request2=db3['Comparador'].resample('B').nunique()

# %%
Quantity_Request_line_max=db2['Comparador'].resample('W').count().max
Quantity_Request_max=db2['Comparador'].resample('W').nunique().max
Quantity_Request_line_min=db2['Comparador'].resample('W').count().min
Quantity_Request_min=db2['Comparador'].resample('W').nunique().min
Quantity_Request_line_median=db2['Comparador'].resample('W').count().median
Quantity_Request_median=db2['Comparador'].resample('W').nunique().median
Quantity_Request_line_mean=db2['Comparador'].resample('W').count().mean
Quantity_Request_mean=db2['Comparador'].resample('W').nunique().mean
Quantity_Request_line_std=db2['Comparador'].resample('W').count().std
Quantity_Request_std=db2['Comparador'].resample('W').nunique().std
Quantity_Request_line_sum=db2['Comparador'].resample('W').count().sum
Quantity_Request_sum=db2['Comparador'].resample('W').nunique().sum

# %%
#https://seaborn.pydata.org/generated/seaborn.jointplot.html
sns.jointplot(x=Quantity_Request_line, y=Quantity_Request,kind="scatter",space=0,).set_axis_labels("Quantity_Request_line", "Quantity_Request");
# Out:
# c:\python27\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#https://seaborn.pydata.org/generated/seaborn.jointplot.html
sns.jointplot(x=Quantity_Request_line2, y=Quantity_Request2,kind="scatter",space=0,).set_axis_labels("Quantity_Request_line", "Quantity_Request");

# %%
#sns.pairplot(db2,x_vars=Quantity_Request_line, y_vars=Quantity_Request, size=7, aspect=0.7, kind='reg').set_axis_labels("Quantity_Request_line", "Quantity_Request");

# %%
def numeric_to_institucion(x):
    if x=='CHL04':
        return 1
    if x=='CHL32':
        return 2
    if x=='CHL02':
        return 3
    if x=='PER03':
        return 4
    if x=='PER05':
        return 5
    if x=='PER06':
        return 6
    if x=='CHL01' or 'CHL05' or 'CHL08' or 'CHL06':
        return 7
    if x=='CHL18' or 'CHL25' or 'CHL28' or 'CHL31':
        return 8
    if x=='Sin institucion':
        return 9
    
db2['Unidad_Negocio_num'] = db2['BUSINESS_UNIT'].apply(numeric_to_institucion)
db2
# Out:
#            BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# REQ_DT
# 2017-01-03         CHL01   81258          0             1             1
# 2017-01-03         CHL01   81259          0             1             1
# 2017-01-03         CHL01   81260          0             1             1
# 2017-01-03         CHL01   81261          0             1             1
# 2017-01-03         CHL01   81262          0             1             1
# 2017-01-03         CHL01   81263          1             1             1
# 2017-01-03         CHL01   81263          1             2             1
# 2017-01-03         CHL01   81263          1             3             1
# 2017-01-03         CHL01   81263          1             4             1
# 2017-01-03         CHL01   81263          1             5             1
# 2017-01-03         CHL01   81263          1             6             1
# 2017-01-03         CHL01   81263          1             7             1
# ...

# %%
def numeric_to_month(x):
    if x=='Enero':
        return 1
    if x=='Febrero':
        return 2
    if x=='Marzo':
        return 3
    if x=='Abril':
        return 4
    if x=='Mayo':
        return 5
    if x=='Junio':
        return 6
    if x=='Julio':
        return 7
    if x=='Agosto':
        return 8
    if x=='Septiembre':
        return 9    
    if x=='Octubre':
        return 10
    if x=='Noviembre':
        return 11   
    if x=='Diciembre':
        return 12   
    
db2['Mes_numerico'] = db2['Mes de requerimiento'].apply(numeric_to_month)
db2
# Out:
#            BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# REQ_DT
# 2017-01-03         CHL01   81258          0             1             1
# 2017-01-03         CHL01   81259          0             1             1
# 2017-01-03         CHL01   81260          0             1             1
# 2017-01-03         CHL01   81261          0             1             1
# 2017-01-03         CHL01   81262          0             1             1
# 2017-01-03         CHL01   81263          1             1             1
# 2017-01-03         CHL01   81263          1             2             1
# 2017-01-03         CHL01   81263          1             3             1
# 2017-01-03         CHL01   81263          1             4             1
# 2017-01-03         CHL01   81263          1             5             1
# 2017-01-03         CHL01   81263          1             6             1
# 2017-01-03         CHL01   81263          1             7             1
# ...

# %%
db2[(db2.BUSINESS_UNIT=='CHL01')|(db2.Mes_numerico==1)]
# Out:
#            BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# REQ_DT
# 2017-01-03         CHL01   81258          0             1             1
# 2017-01-03         CHL01   81259          0             1             1
# 2017-01-03         CHL01   81260          0             1             1
# 2017-01-03         CHL01   81261          0             1             1
# 2017-01-03         CHL01   81262          0             1             1
# 2017-01-03         CHL01   81263          1             1             1
# 2017-01-03         CHL01   81263          1             2             1
# 2017-01-03         CHL01   81263          1             3             1
# 2017-01-03         CHL01   81263          1             4             1
# 2017-01-03         CHL01   81263          1             5             1
# 2017-01-03         CHL01   81263          1             6             1
# 2017-01-03         CHL01   81263          1             7             1
# ...

# %%
#Se rescata el mes y la semana.
#https://chrisalbon.com/machine_learning/preprocessing_dates_and_times/break_up_dates_and_times_into_multiple_features/

db2['week'] = db2['APPROVAL_DT'].dt.week
db2['month'] = db2['APPROVAL_DT'].dt.month

# %%
db2.dtypes
# Out:
# BUSINESS_UNIT                        object
# REQ_ID                                int64
# Solicitud                             int64
# REQ_LINE_NBR                          int64
# REQ_LN_SCHED                          int64
# DISTRIB_LINE_REQ                      int64
# REQ_STATUS                           object
# BUDGET_HDR_STATUS                    object
# REQUESTOR_ID                         object
# ACCOUNT                               int64
# DEPTID                              float64
# OPERATING_UNIT                        int64
# PRODUCT                             float64
# CHARTFIELD2                         float64
# CHARTFIELD3                          object
# PROJECT_ID                           object
# AFFILIATE                           float64
# INV_ITEM_ID                          object
# ITM_ID_VNDR                          object
# DESCR                                object
# QTY_REQ                             float64
# ...

# %%
A=db2.reset_index(drop=True)
A
# Out:
#        BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# 0              CHL01   81258          0             1             1
# 1              CHL01   81259          0             1             1
# 2              CHL01   81260          0             1             1
# 3              CHL01   81261          0             1             1
# 4              CHL01   81262          0             1             1
# 5              CHL01   81263          1             1             1
# 6              CHL01   81263          1             2             1
# 7              CHL01   81263          1             3             1
# 8              CHL01   81263          1             4             1
# 9              CHL01   81263          1             5             1
# 10             CHL01   81263          1             6             1
# 11             CHL01   81263          1             7             1
# 12             CHL01   81263          1             8             1
# ...

# %%
A.fillna(0)
# Out:
#        BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# 0              CHL01   81258          0             1             1
# 1              CHL01   81259          0             1             1
# 2              CHL01   81260          0             1             1
# 3              CHL01   81261          0             1             1
# 4              CHL01   81262          0             1             1
# 5              CHL01   81263          1             1             1
# 6              CHL01   81263          1             2             1
# 7              CHL01   81263          1             3             1
# 8              CHL01   81263          1             4             1
# 9              CHL01   81263          1             5             1
# 10             CHL01   81263          1             6             1
# 11             CHL01   81263          1             7             1
# 12             CHL01   81263          1             8             1
# ...

# %%
#A.dtypes
print(type(A))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
A=db2[(db2.BUSINESS_UNIT=='CHL02')].reset_index(drop=True)

# %%
#print(type(A))
#A.dtypes
#A.shape
A
# Out:
#       BUSINESS_UNIT  REQ_ID  Solicitud  REQ_LINE_NBR  REQ_LN_SCHED  \
# 0             CHL02   31424          0             1             1
# 1             CHL02   31425          0             1             1
# 2             CHL02   31426          0             1             1
# 3             CHL02   31427          0             1             1
# 4             CHL02   31428          0             1             1
# 5             CHL02   31429          0             1             1
# 6             CHL02   31430          0             1             1
# 7             CHL02   31431          0             1             1
# 8             CHL02   31432          1             1             1
# 9             CHL02   31432          0             2             1
# 10            CHL02   31433          0             1             1
# 11            CHL02   31434          0             1             1
# 12            CHL02   31435          1             1             1
# ...

# %%
feature_cols = ['Unidad_Negocio_num', 'Mes_numerico']

# %%
A1 = A.loc[:2000, feature_cols]

# %%
#A1.values
A1.get_values
# Out:
# <bound method DataFrame.get_values of       Unidad_Negocio_num  Mes_numerico
# 0                      3             1
# 1                      3             1
# 2                      3             1
# 3                      3             1
# 4                      3             1
# 5                      3             1
# 6                      3             1
# 7                      3             1
# 8                      3             1
# 9                      3             1
# 10                     3             1
# 11                     3             1
# 12                     3             1
# 13                     3             1
# 14                     3             1
# 15                     3             1
# 16                     3             1
# 17                     3             1
# 18                     3             1
# 19                     3             1
# 20                     3             1
# 21                     3             1
# ...

# %%
#np.ravel(A1)

# %%
A1.shape
# Out:
# (2001, 2)

# %%
print(type(A1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
feature_cols2 = ['MERCH_AMT_BSE']

# %%
A2 = A.loc[:2000, feature_cols2]
#y = A.MERCH_AMT_BSE

# %%
A2.shape
# Out:
# (2001, 1)

# %%
#A2.values
A2.get_values
# Out:
# <bound method DataFrame.get_values of       MERCH_AMT_BSE
# 0          666667.0
# 1          199998.0
# 2          666667.0
# 3          369748.0
# 4          150000.0
# 5          714286.0
# 6         1844418.0
# 7           27580.0
# 8           29660.0
# 9           26908.0
# 10         476303.0
# 11         300000.0
# 12        2327202.0
# 13        2327202.0
# 14        2327202.0
# 15        2327202.0
# 16          77400.0
# 17           2158.0
# 18           1584.0
# 19         300000.0
# 20         300000.0
# 21       16897912.0
# 22       16899230.0
# 23       16899230.0
# 24       16899230.0
# 25       16899230.0
# 26       16899230.0
# 27       16899230.0
# 28       16899230.0
# 29       16899230.0
# ...             ...
# 1971        84000.0
# 1972        84000.0
# 1973        84000.0
# 1974        84000.0
# 1975        84000.0
# 1976        84000.0
# 1977        84000.0
# 1978        84000.0
# 1979        84000.0
# 1980        84000.0
# 1981       114000.0
# ...

# %%
#https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.ravel.html
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.values.html#pandas.DataFrame.values

#np.ravel(A2)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(A1,A2)
logreg.predict(A1)
y_pred = logreg.predict(A1)
len(y_pred)
# Out:
# c:\python27\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python27\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\python27\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 2001

# %%
from sklearn import metrics
print(metrics.accuracy_score(A2, y_pred))
# Out:
# 0.04047976011994003

# %% [markdown]
# ### Neigbors = 5

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(A1,A2)
y_pred = knn.predict(A1)
print(metrics.accuracy_score(A2, y_pred))
# Out:
# 0.0014992503748125937
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# ### Grafica de centroides

# %% [markdown]
# ### https://datatofish.com/k-means-clustering-python/

# %%
H1=db2[(db2.BUSINESS_UNIT=='CHL02')].reset_index(drop=True)

# %%
H2=db2[(db2.BUSINESS_UNIT=='CHL01')].reset_index(drop=True)

# %%
H3=db2[(db2.BUSINESS_UNIT=='CHL04')].reset_index(drop=True)

# %%
B1= H1.loc[:2000 , ['MERCH_AMT_BSE','Mes_numerico']]

# %%
B2= H2.loc[:2000 , ['MERCH_AMT_BSE','Mes_numerico']]

# %%
B3= H3.loc[:2000 , ['MERCH_AMT_BSE','Mes_numerico']]

# %%
B1.get_values
# Out:
# <bound method DataFrame.get_values of       MERCH_AMT_BSE  Mes_numerico
# 0          666667.0             1
# 1          199998.0             1
# 2          666667.0             1
# 3          369748.0             1
# 4          150000.0             1
# 5          714286.0             1
# 6         1844418.0             1
# 7           27580.0             1
# 8           29660.0             1
# 9           26908.0             1
# 10         476303.0             1
# 11         300000.0             1
# 12        2327202.0             1
# 13        2327202.0             1
# 14        2327202.0             1
# 15        2327202.0             1
# 16          77400.0             1
# 17           2158.0             1
# 18           1584.0             1
# 19         300000.0             1
# 20         300000.0             1
# 21       16897912.0             1
# 22       16899230.0             1
# 23       16899230.0             1
# 24       16899230.0             1
# ...

# %%
B2.get_values
# Out:
# <bound method DataFrame.get_values of       MERCH_AMT_BSE  Mes_numerico
# 0           17684.0             1
# 1           29916.0             1
# 2           30848.0             1
# 3           30848.0             1
# 4         1220214.0             1
# 5            2836.0             1
# 6            1964.0             1
# 7            1204.0             1
# 8            2526.0             1
# 9            6620.0             1
# 10           3290.0             1
# 11            908.0             1
# 12           4504.0             1
# 13           2900.0             1
# 14          38440.0             1
# 15           9825.0             1
# 16          15730.0             1
# 17           1308.0             1
# 18           2724.0             1
# 19           2730.0             1
# 20           8210.0             1
# 21          15264.0             1
# 22           1294.0             1
# 23            941.0             1
# 24           1188.0             1
# ...

# %%
B3.get_values
# Out:
# <bound method DataFrame.get_values of       MERCH_AMT_BSE  Mes_numerico
# 0            7840.0             1
# 1            7840.0             1
# 2            7840.0             1
# 3            3470.0             1
# 4            4813.0             1
# 5           15650.0             1
# 6           32860.0             1
# 7          113245.0             1
# 8         4162500.0             1
# 9          132000.0             1
# 10          35000.0             1
# 11          25750.0             1
# 12        1897361.0             1
# 13        1897361.0             1
# 14       16443792.0             1
# 15          31515.0             1
# 16          32250.0             1
# 17           1500.0             1
# 18          26000.0             1
# 19           5500.0             1
# 20           5500.0             1
# 21          10500.0             1
# 22           3024.0             1
# 23         286000.0             1
# 24         136000.0             1
# ...

# %%
B1.shape
# Out:
# (2001, 2)

# %%
B2.shape
# Out:
# (2001, 2)

# %%
B3.shape
# Out:
# (2001, 2)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10).fit(B1)

# %%
centroids = kmeans.cluster_centers_

# %%
print(centroids)
# Out:
# [[7.89470444e+04 1.33162393e+00]
#  [1.13445378e+08 1.00000000e+00]
#  [8.64016488e+06 1.37500000e+00]
#  [1.82941177e+08 1.00000000e+00]
#  [3.20541543e+07 1.00000000e+00]
#  [1.39502166e+07 1.00000000e+00]
#  [4.30085405e+06 1.13953488e+00]
#  [5.24604085e+07 1.00000000e+00]
#  [1.53191697e+06 1.22377622e+00]
#  [1.74756729e+07 1.00000000e+00]]

# %%
plt.scatter(B1['Mes_numerico'], B1['MERCH_AMT_BSE'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)

# %% [markdown]
# ### Neigbors

# %%
knn = KNeighborsClassifier(n_neighbors=40)
knn.fit(A1,A2)
y_pred = knn.predict(A1)
print(metrics.accuracy_score(A2, y_pred))
# Out:
# 0.006496751624187906
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# ### Realizando division del dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(A1,A2, test_size=0.4, random_state=4)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.03870162297128589

# %% [markdown]
# ### Evaluando el mejor valor de K

# %%
k_range = list(range(1, 80))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """

# %%
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0,0.5,'Testing Accuracy')

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# 10-fold cross-validation with K=5 for KNN (the n_neighbors parameter)
knn = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn, A1, A2, cv=10, scoring='accuracy')
print(scores)
# Out:
# c:\python27\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# [0.00702576 0.         0.         0.         0.01923077 0.
#  0.         0.         0.         0.        ]
# c:\python27\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
# use average accuracy as an estimate of out-of-sample accuracy
print(scores.mean())
# Out:
# 0.002625653035489101

# %%
# search for an optimal value of K for KNN
k_range = list(range(1, 31))
k_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, A1, A2, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())
print(k_scores)
# Out:
# [0.00400228187113433, 0.0014894613583138175, 0.002625653035489101, 0.002625653035489101, 0.002625653035489101, 0.002625653035489101, 0.002079204948057407, 0.002079204948057407, 0.000156128024980484, 0.000156128024980484, 0.000156128024980484, 0.000156128024980484, 0.000234192037470726, 0.000156128024980484, 0.000156128024980484, 0.000156128024980484, 0.000156128024980484, 0.0004638203326727917, 0.0004638203326727917, 0.0012902666136645272, 0.0026235999469978607, 0.0026235999469978607, 0.0026235999469978607, 0.0026235999469978607, 0.0034500462279895964, 0.00478337956132293, 0.00478337956132293, 0.00478337956132293, 0.00478337956132293, 0.003956933280331194]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# plot the value of K for KNN (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0,0.5,'Cross-Validated Accuracy')

# %% [markdown]
# #### Cross-validation example: model selection
# Goal: Compare the best KNN model with logistic regression on the iris dataset

# %%
# 10-fold cross-validation with the best KNN model
knn = KNeighborsClassifier(n_neighbors=25)
print(cross_val_score(knn, A1, A2, cv=10, scoring='accuracy').mean())
# Out:
# 0.0034500462279895964

# %%
# 10-fold cross-validation with logistic regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
print(cross_val_score(logreg, A1, A2, cv=10, scoring='accuracy').mean())
# Out:
# 0.17047367730004473

# %% [markdown]
# #### Cross-validation example: feature selection
#
# Goal: Select whether the Unidad_Negocio_num feature should be included in the linear regression model on the advertising dataset

# %%
# create a Python list of three feature names
feature_cols3 = ['Unidad_Negocio_num', 'Mes_numerico']

# select the MERCH_AMT_BSE column as the response (y)
#feature_cols2 = ['MERCH_AMT_BSE']

# %%
A3 = A.loc[:2000, feature_cols3]

# %%
A3.get_values
# Out:
# <bound method DataFrame.get_values of       Unidad_Negocio_num  Mes_numerico
# 0                      3             1
# 1                      3             1
# 2                      3             1
# 3                      3             1
# 4                      3             1
# 5                      3             1
# 6                      3             1
# 7                      3             1
# 8                      3             1
# 9                      3             1
# 10                     3             1
# 11                     3             1
# 12                     3             1
# 13                     3             1
# 14                     3             1
# 15                     3             1
# 16                     3             1
# 17                     3             1
# 18                     3             1
# 19                     3             1
# 20                     3             1
# 21                     3             1
# ...

# %%
A3.shape
# Out:
# (2001, 2)

# %%
# 10-fold cross-validation with all three features
lm = LogisticRegression()
scores = cross_val_score(lm, A3, A2, cv=10, scoring='neg_mean_squared_error')
print(scores)
# Out:
# [-4.66840662e+13 -3.88240067e+12 -7.75244152e+12 -1.24669681e+13
#  -1.78470248e+13 -1.71240042e+13 -2.40244334e+13 -2.48824130e+13
#  -2.67456882e+13 -3.02328789e+13]

# %%
# fix the sign of MSE scores
mse_scores = -scores
print(mse_scores)
# Out:
# [4.66840662e+13 3.88240067e+12 7.75244152e+12 1.24669681e+13
#  1.78470248e+13 1.71240042e+13 2.40244334e+13 2.48824130e+13
#  2.67456882e+13 3.02328789e+13]

# %%
# convert from MSE to RMSE
rmse_scores = np.sqrt(mse_scores)
print(rmse_scores)
# Out:
# [6832573.90555539 1970380.8448842  2784320.65695545 3530859.40114208
#  4224573.9164601  4138116.02271024 4901472.57776939 4988227.43698183
#  5171623.36166011 5498443.31372065]

# %%
# calculate the average RMSE
print(rmse_scores.mean())
# Out:
# 4404059.143783945

# %%
# 10-fold cross-validation with two features (excluding Newspaper), 
# se resumen los pasos anteriores como cambio de signo, elevar al cuadrado y calcular el promedio.
feature_cols = ['Mes_numerico']
X = A3[feature_cols]
print(np.sqrt(-cross_val_score(lm, A3, A2, cv=10, scoring='neg_mean_squared_error')).mean())
# Out:
# 4404059.143783945

# %% [markdown]
# ### https://github.com/justmarkham/scikit-learn-videos/blob/master/07_cross_validation.ipynb

# %% [markdown]
# ### Improvements to cross-validation
#
# #### Repeated cross-validation
#
# Repeat cross-validation multiple times (with different random splits of the data) and average the results
# More reliable estimate of out-of-sample performance by reducing the variance associated with a single trial of cross-validation
#
# ### Creating a hold-out set
#
# "Hold out" a portion of the data before beginning the model building process
# Locate the best model using cross-validation on the remaining data, and test it using the hold-out set
# More reliable estimate of out-of-sample performance since hold-out set is truly out-of-sample
#
# ### Feature engineering and selection within cross-validation iterations
#
# Normally, feature engineering and selection occurs before cross-validation
# Instead, perform all feature engineering and selection within each cross-validation iteration
# More reliable estimate of out-of-sample performance since it better mimics the application of the model to out-of-sample data

# %% [markdown]
# ### Graficar

# %% [markdown]
# #### https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html
# #### https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html

# %%
#ax.scatter3D

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-03245d8677e1> in <module>()
# ----> 1 plt.plot(x, y, '-p', color='gray',
#       2          markersize=15, linewidth=4,
#       3          markerfacecolor='white',
#       4          markeredgecolor='gray',
#       5          markeredgewidth=2)
#
# NameError: name 'x' is not defined

# %%
A=db2.reset_index(drop=True).fillna(0)

# %%
#A.loc[:2000, feature_cols3]
#A.dtypes
scatter1 = A.loc[:,'Unidad_Negocio_num',]
scatter2 = A.loc[:,'MERCH_AMT_BSE']
scatter2 = A.loc[:,'Mes_numerico']



# create figure        
fig = plt.figure(dpi=200)
ax = fig.gca(projection='3d')
#ax.set_axis_off()
ax.scatter(scatter1,scatter2,scatter2, marker='o', s = 64, alpha=0.5)    
ax.set_xlim(0, 10)
ax.set_ylim(0, 20000000000)
ax.set_zlim(0, 12)

ax.set_title("BU - MERCH_BSE - Mes", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("Unidad_Negocio")
ax.set_ylabel("MERCH_AMT_BSE")
ax.set_zlabel("Mes_numerico")

plt.show()


#plt.plot(scatter1, scatter2,markersize=2,color='r')
#plt.legend(numpoints=1)
#plt.xlim(0, 80);
#plt.ylim(0, 80);

# %%
scatter1

# %%
plt.scatter(iris, features, alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
#filtered_data = df[(df.price > 11.99) & (df.topping == 'Pineapple')]

#topping_type = []

#for row in df.topping:
    #if row in ['pepperoni', 'chicken', 'anchovies']:
        #topping_type.append('meat')
    #else:
        #topping_type.append('vegetable')
#df['topping_type'] = topping_type

#https://jeffdelaney.me/blog/useful-snippets-in-pandas/
#https://www.ritchieng.com/pandas-apply/
#https://engineering.upside.com/a-beginners-guide-to-optimizing-pandas-code-for-speed-c09ef2c6a4d6
#https://chrisalbon.com/machine_learning/preprocessing_dates_and_times/calculate_difference_between_dates_and_times/
#http://jonathansoma.com/lede/foundations/classes/pandas%20columns%20and%20functions/apply-a-function-to-every-row-in-a-pandas-dataframe/

def diferencia_fecha(row):
        return row['Fec/Hor Ult Actualizacion']- row['APPROVAL_DT']
#A.apply(diferencia_fecha, axis=1)
A['resta_fecha'] = A.apply(diferencia_fecha,axis=1)

#A['resta_fecha'] = A.apply(diferencia_fecha)
#A['resta_fecha']=(A['BUDGET_DT'] - A['APPROVAL_DT']).apply(diferencia_fecha)

# %%
X = A[['Unidad_Negocio_num', 'MERCH_AMT_BSE','week']]
#sns.jointplot(x=Cantidad de lineas, y=Unidad_Negocio_num,kind="scatter")
#data.hist(figsize = (20, 20))
#plt.show()

# %%
#print(type(X))
#print(X.shape)
print(X)

# %%
X1 = X.fillna(0) #Siempre limpiar la matriz, para que pueda graficar el Pairplot
print(X1)

# %%
print(type(X1))
print(X1.shape)

# %%
sns.set(style="ticks", color_codes=True)
#sns.load_dataset(X)
g = sns.pairplot(X1)
#sns.set(style="ticks", color_codes=True)
#sns.load_dataset(db2)
#g = sns.pairplot(db2)

# %%
A2=pd.read_excel('solicitudes.xlsx','Hoja1', parse_dates=['REQ_DT'])

# %%
feature_cols = ['Unidad_Negocio_num', 'MERCH_AMT_BSE']

# %%
X1 = X.loc[:, feature_cols]

# %%
dataset = X1.drop("MERCH_AMT_BSE", axis=1)

# %%
X1=X1.reset_index()

# %%
print(X1.shape)

# %%
# create a numpy array with the numeric values for input into scikit-learn 
numpy_array = X1.array()

# %%
X = numpy_array[:, 1:] # select columns 1 through end 
y = numpy_array[:, 0] # select column 0, the stock price 
#https://coredump.uno/questions/11023411/how-to-import-csv-data-file-into-scikitlearn
#https://datascience.stackexchange.com/questions/26678/k-means-program-in-python-for-large-excel-database
#https://machinelearningmastery.com/how-to-load-data-in-python-with-scikit-learn/

# %%
print(y)

# %%
X.valuecounts()

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors = 15

# we only take the first two features. We could avoid this ugly
# slicing by using a two-dim dataset
X = db2.Mes_numerico
y = db2.Unidad_Negocio_num

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    #clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
                edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))

plt.show()

# %%
A=db2.columns[1:]

# %%
featuresAll=[]
features = X[:,2]
features.shape

# %%
#Finding the relationship between Sepal Length and Sepal width
#featuresAll = []
#targets = []
#for feature in features:
#    featuresAll.append(feature[0]) #Sepal length
#    targets.append(feature[1]) #sepal width
#X = A[['Unidad_Negocio_num', 'MERCH_AMT_BSE','week']]
groups = ('1','2','3','4','5','6','7','8','9')
colors = ('red','red','red','red','red','red','green','red','red')

#X = ((db2.Mes_numerico [:52909], db2.Unidad_Negocio_num[:50]), (db2.week[50:100], db2.Unidad_Negocio_num[50:100]), 
       (db2.week[100:150], db2.Unidad_Negocio_num[100:150]))


# X = (db2.Mes_numerico, db2.Unidad_Negocio_num)


for item, color, group in zip(X,colors,groups): 
    #item = (featuresAll[:50], targets[:50]), (featuresAll[50:100], targets[50:100]), (featuresAll[100:150], targets[100:150])
    x, y = item
    plt.scatter(x,y,color=color,alpha=1)
    plt.title('Iris Dataset scatter Plot')
plt.xlabel('sepal length')
plt.ylabel('Sepal width')
plt.show()

# %%
#Finding the relationship between Sepal Length and Sepal width
#featuresAll = []
#targets = []
#for feature in features:
#    featuresAll.append(feature[0]) #Sepal length
#    targets.append(feature[1]) #sepal width
#X = A[['Unidad_Negocio_num', 'MERCH_AMT_BSE','week']]
groups = ('1','2','3','4','5','6','7','8','9')
colors = ('red','red','red','red','red','red','green','red','red')


y=X1.week
x=X1.Unidad_Negocio_num
plt.scatter(x,y,color=color)
plt.title('Iris Dataset scatter Plot')
plt.xlabel('Unidad_Negocio')
plt.ylabel('Mes')
plt.show()

# %%
#X1.reset_index(drop=True, inplace=True)
X1.set_index(['Unidad_Negocio_num'], inplace=True)

# %%
print(X1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
#d=[X1.week, X1.MERCH_AMT_BSE]
d=X1.MERCH_AMT_BSE
f=X1.week
print(d)
#knn.fit(d, f)
#y_pred = knn.predict(x)
#print(metrics.accuracy_score(y, y_pred))

# %%
g = sns.PairGrid(X1)
#g.map_diag(plt.hist)
#g.map_offdiag(plt.scatter);

# %%
X1.hist(figsize = (7,7))
plt.show()

# %% [markdown]
# ### Conteo unico de las Request ID por cuarter

# %%
db2['Comparador'].resample('Q').nunique()

# %%
db3['Comparador'].resample('Q').nunique()

# %% [markdown]
# ### Conteo de las lineas de los Request por Quarter

# %%
#http://benalexkeen.com/resampling-time-series-data-with-pandas/
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html
db2['Comparador'].resample('Q').count().plot()
db3['Comparador'].resample('Q').count().plot()

# %% [markdown]
# ### Conteo total de Request por Quarter

# %%
db2['Comparador'].resample('Q').nunique().plot()
db3['Comparador'].resample('Q').nunique().plot()

# %%
A1=db2['Comparador'].resample('M').count().plot()
B1=db3['Comparador'].resample('M').count().plot()

# %%
A2=db2['Comparador'].resample('M').nunique().plot()
B2=db3['Comparador'].resample('M').nunique().plot()

# %%
# create a Python list of feature names
feature_cols = ['TV', 'Radio', 'Newspaper']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]

# equivalent command to do this in one line
X = data[['TV', 'Radio', 'Newspaper']]

# print the first 5 rows
X.head()

# check the type and shape of X
print(type(X)) #must be DataFrame
print(X.shape)

# select a Series from the DataFrame
y = data['Sales']

# equivalent command that works if there are no spaces in the column name
y = data.Sales

# print the first 5 values
y.head()

# %% [markdown]
# <font color='black'><Bold>**Cantidad de Solicitante mensual**</font><br>

# %%
#Encuentra la cantidad de Requestors segun BU, linea 1 y en Enero (Mensual)
BU='AIEP'
A3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Enero')).nunique()
B3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Febrero')).nunique()
C3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Marzo')).nunique()
D3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Abril')).nunique()
E3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Mayo')).nunique()
F3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Junio')).nunique()
G3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Julio')).nunique()
H3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Agosto')).nunique()
I3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Septiembre')).nunique()
J3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Octubre')).nunique()
K3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Noviembre')).nunique()
L3=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Diciembre')).nunique()

Y3=[A3,B3,C3,D3,E3,F3,G3,H3,I3,J3,K3,L3]
X3=["Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre","Octubre","Noviembre","Diciembre"]
sns.barplot(X3, Y3)

Y3

# %% [markdown]
# <font color='black'><Bold>**Cantidad de PR / Requestors (mensual)**</font><br>

# %%
#Encuentra la cantidad de Requestors segun BU, linea 1 y en Enero (Mensual)
BU='AIEP'
A4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Enero')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Enero')).nunique()
B4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Febrero')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Febrero')).nunique()
C4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Marzo')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Marzo')).nunique()
D4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Abril')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Abril')).nunique()
E4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Mayo')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Mayo')).nunique()
F4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Junio')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Junio')).nunique()
G4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Julio')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Julio')).nunique()
H4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Agosto')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Agosto')).nunique()
I4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Septiembre')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Septiembre')).nunique()
J4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Octubre')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Octubre')).nunique()
K4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Noviembre')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Noviembre')).nunique()
L4=db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['Comparador'].get_group((BU,1,'Diciembre')).nunique()/db2.groupby(['Insitucion','Cantidad de lineas','Mes de requerimiento'])['REQUESTOR_ID'].get_group((BU,1,'Diciembre')).nunique()

Y4=[A4,B4,C4,D4,E4,F4,G4,H4,I4,J4,K4,L4]
X4=["Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre","Octubre","Noviembre","Diciembre"]
sns.barplot(X4, Y4)

Y4

# %% [markdown]
# <font color='black'><Bold>**Desglose de REQ_ID por Institucion y cantidad de 'REQ_LINE_NBR'**</font><br>

# %%
#db1 = db.groupby("BUSINESS_UNIT")#dividiendo segun institucion
#a=db1.get_group('CHL01') #obteniendo solamente la informacion de CHL01
#CHL01=db.groupby(["BUSINESS_UNIT"])['REQ_ID','REQ_LINE_NBR'].get_group('CHL01')
#A=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group(('CHL01')).count()
#B=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',1)).count()
B=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR','Mes de requerimiento'])['REQ_ID'].get_group(('AIEP',1,'Enero')).value_counts()
B
#np.arange(0, 1.0+0.155, 0.155)
#np.multiply(np.divide(B,A, dtype=float), 100)
#np.multiply(np.divide(db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',1)).count(),db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group(('CHL01')).count(), dtype=float), 100)
#C=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',2)).count()
#D=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',3)).count()
#E=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',4)).count()
#F=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',5)).count()
#G=db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',6)).count()
#total=np.sum([B, C,D,E,F,G])
#np.multiply(np.divide(total,A, dtype=float), 100)
#CHL01=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL01').value_counts()
#{"REQ_LINE_NBR":["1","2"]}
#CHL01=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL01').counts()
#CHL01.describe()
#CHL01

# %% [markdown]
# <font color='black'><Bold>**Desglose de REQ_ID por Institucion y cantidad de 'REQ_LINE_NBR'**</font><br>

# %%
unit2='UDLA'
Total_PR=db2.groupby(['Insitucion'])['REQ_ID'].get_group(unit2).nunique()
Total_Lineas=db2.groupby(['Insitucion'])['REQ_ID'].get_group(unit2).count()
Lineas_11=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,11)).count()
Lineas_10=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,10)).count()
Lineas_9=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,9)).count()
Lineas_8=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,8)).count()
Lineas_7=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,7)).count()
Lineas_6=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,6)).count()
Lineas_5=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,5)).count()
Lineas_4=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,4)).count()
Lineas_3=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,3)).count()
Lineas_2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,2)).count()
Lineas_1=db2.groupby(['Insitucion','Cantidad de lineas'])['REQ_ID'].get_group((unit2,1)).count()

Solo_1=Lineas_1-Lineas_2
Solo_2=Lineas_2-Lineas_3
Solo_3=Lineas_3-Lineas_4
Solo_4=Lineas_4-Lineas_5
Solo_5=Lineas_5-Lineas_6
Solo_6=Lineas_6-Lineas_7
Solo_7=Lineas_7-Lineas_8
Solo_8=Lineas_8-Lineas_9
Solo_9=Lineas_9-Lineas_10
Solo_10=Lineas_10-Lineas_11


#value_counts()
#reset_index()
#unique()
#
#
#np.multiply(np.divide(db.groupby(['BUSINESS_UNIT','REQ_LINE_NBR'])['REQ_ID'].get_group(('CHL01',1)).count(),db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group(('CHL01')).count(), dtype=float), 100)
#array [B,C,D,E]
[Total_PR,Total_Lineas,Solo_1,Solo_2,Solo_3,Solo_4,Solo_5,Solo_6,Solo_7,Solo_8,Solo_9,Solo_10]
#[Total_PR,Total,np.multiply(np.divide(B,Total,dtype=float),100),np.multiply(np.divide(C,Total,dtype=float),100),np.multiply(np.divide(D,Total,dtype=float),100),np.multiply(np.divide(E,Total,dtype=float),100),np.multiply(np.divide(F,Total,dtype=float),100),np.multiply(np.divide(G,Total,dtype=float),100),np.multiply(np.divide(H,Total,dtype=float),100),np.multiply(np.divide(I,Total,dtype=float), 100),np.multiply(np.divide(J,Total, dtype=float),100),np.multiply(np.divide(K,Total, dtype=float),100)]

# %%
Porcentual_1=(Solo_1/Lineas_1)*100
Porcentual_2=Solo_2/Lineas_1
Porcentual_3=Solo_3/Lineas_1
Porcentual_4=Solo_4/Lineas_1
Porcentual_5=Solo_5/Lineas_1
Porcentual_6=Solo_6/Lineas_1
Porcentual_7=Solo_7/Lineas_1

[Total_PR,Total_Lineas,Porcentual_1,Porcentual_2,Porcentual_3,Porcentual_4,Porcentual_5,Porcentual_6]

# %%
#db2.Cantidad de lineas==1('Insitucion')
db2.groupby('Insitucion').REQ_ID.nunique().reset_index().sort_values('REQ_ID', ascending=False) #cantidad PR
#db2.groupby('Insitucion').REQ_ID.count().reset_index().sort_values('REQ_ID', ascending=False) #cantidad lineas

#[Total_PR,Total_Lineas,Solo_10,Solo_9,Solo_8,Solo_7,Solo_6,Solo_5,Solo_4,Solo_3,Solo_2,Solo_1]

# %%
resumen=db.fillna("0")
resumen.pivot_table(index='BUSINESS_UNIT',columns='REQ_LINE_NBR',margins=True,aggfunc='count',fill_value=0)

# %%
resumenes=db.fillna("0")
resumenes.pivot_table(index=['BUSINESS_UNIT'],columns='REQ_LINE_NBR',margins=True,aggfunc='count',fill_value=0)

# %%
#db.groupby('BUSINESS_UNIT').REQ_LINE_NBR.sum().reset_index().sort_values('REQ_LINE_NBR', ascending=False)
db.groupby('BUSINESS_UNIT').REQ_LINE_NBR.count().reset_index().sort_values('REQ_LINE_NBR', ascending=False)

# %%
#g=CHL01[CHL01['REQ_LINE_NBR']>1]
#sns.distplot(g);

# %%
#SCHL01=db2.get_group('CHL01')
SCHL01=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL01')
C2=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UNAB',1)).nunique()
#sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR', data=a, kind="reg",kind="kde");
x=db2.groupby(['Insitucion','Cantidad de lineas'])['REQUESTOR_ID'].get_group(('UNAB',1)).nunique()
sns.jointplot(x='Solicitud', y='REQ_LINE_NBR',data=SCHL01, kind="kde");

# %% [markdown]
# # Ahora se realiza analisis para todas las instituciones

# %%
CHL01=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL01').value_counts().plot.hist(bins=10)

# %%
CHL02=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').value_counts().plot.hist(bins=10)

# %%
CHL022=db.groupby(['BUSINESS_UNIT'])['REQ_LINE_NBR'].get_group('CHL02').describe(percentiles=[.25, .5, .75])
#CHL022=db.groupby(['BUSINESS_UNIT'])['REQ_LINE_NBR'].get_group('CHL02').value_counts(bins=20).plot.hist()
#CHL022=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').mode()
#CHL022=db.groupby(['BUSINESS_UNIT'])['REQ_LINE_NBR'].get_group('CHL02').quantile([.25, .5, .75])
CHL022

# %%
#db[db['REQ_LINE_NBR']>100]
CHL02212=db.groupby(['BUSINESS_UNIT'])['REQ_LINE_NBR'].get_group('CHL02').agg({'REQ_ID'})
#CHL02212>20
CHL02212

# %%
CHL02_mayores=db.groupby(['BUSINESS_UNIT'])['REQ_LINE_NBR'].get_group('CHL02').value_counts().describe()
CHL02_mayores

# %%
#CHL022=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').value_counts()
CHL02_mayores=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').count()
#porcentaje=CHL022.value_counts()/CHL02.value_counts()
#porcentaje
#porcentaje == CHL02_mayores.count()/CHL02.count()
#porcentaje
#CHL022
CHL02_mayores

# %%
CHL04=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL04').value_counts().plot.hist(bins=10)

# %%
CHL05=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL05').value_counts().plot.hist(bins=20)

# %%
CHL06=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL06').value_counts().plot.hist(bins=20)

# %%
CHL08=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL08').value_counts().plot.hist(bins=20)

# %%
CHL18=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL18').value_counts().plot.hist(bins=20)

# %%
CHL25=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL25').value_counts().plot.hist(bins=20)

# %%
CHL28=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL28').value_counts().plot.hist(bins=20)

# %%
CHL31=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL31').value_counts().plot.hist(bins=10)

# %%
CHL32=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL32').value_counts().plot.hist(bins=20)

# %%
PER03=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('PER03').value_counts().plot.hist(bins=20)

# %%
PER05=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('PER05').value_counts().plot.hist(bins=20)

# %%
PER06=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('PER06').value_counts().plot.hist(bins=20)

# %%
SCHL04=db.get_group('CHL04')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL04, kind="kde");

# %%
SCHL05=db2.get_group('CHL05')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL05, kind="kde");

# %%
SCHL08=db2.get_group('CHL08')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL08, kind="kde");

# %%
SCHL18=db.get_group('CHL18')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL18, kind="kde");

# %%
SCHL25=db2.get_group('CHL25')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL25, kind="kde");

# %%
SCHL28=db2.get_group('CHL28')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL28, kind="kde");

# %%
SCHL31=db2.get_group('CHL31')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL31, kind="kde");

# %%
SCHL32=db2.get_group('CHL32')
sns.jointplot(x='REQ_ID', y='REQ_LINE_NBR',data=SCHL32, kind="kde");

# %%
#CHL02=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').value_counts()
#CHL02=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').value_counts().describe()
CHL02=db.groupby(['BUSINESS_UNIT'])['REQ_ID'].get_group('CHL02').value_counts().hist()

# %%
df.pivot_table(index="Business Unit",columns="Mes de entrada",values="DISTRIB_LINE_REQ")

# %%
df[df['Sla Presentacion']>100]

# %%
db({"REQ_LINE_NBR":["1","2"]})

# %%
from sklearn import cluster, datasets

# %%
iris = datasets.load_iris()

# %%
X_iris = iris.data

# %%
y_iris = iris.target

# %%
k_means = cluster.KMeans(n_clusters=3)

# %%
k_means.fit(X_iris)

# %%
print(k_means.labels_[::10])

# %%
print(y_iris[::10])

# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris_X = iris.data

# %%
iris_y = iris.target

# %%
np.unique(iris_y)
